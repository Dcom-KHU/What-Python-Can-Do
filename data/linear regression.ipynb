# %% [markdown]
# # 선형 회귀
# 하나하나 실행해 보세용 ><

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
vectors_set = []

for i in range(1000):
    x1 = np.random.normal(0.0, 0.55)  # 정규 분포
    y1 = x1 * 0.1 + 0.3 + np.random.normal(0.0, 0.03)
    vectors_set.append([x1, y1])

x_data = [v[0] for v in vectors_set]
y_data = [v[1] for v in vectors_set]

plt.plot(x_data, y_data, 'ro')
plt.show()

# %%
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

loss = tf.reduce_mean(tf.square(y - y_data))

optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

init = tf.global_variables_initializer()

sess = tf.Session()
sess.run(init)

# %%
for step in range(8):
    sess.run(train)
    print(step, sess.run(W), sess.run(b))
    print(step, sess.run(loss))
    
    # 그래픽 표시
    plt.plot(x_data, y_data, 'ro')
    plt.plot(x_data, sess.run(W) * x_data + sess.run(b))
    plt.xlabel('x')
    plt.xlim(-2, 2)
    plt.ylim(0.1, 0.6)
    plt.ylabel('y')
    plt.show()
# Out:
# 0 [0.66654354] [0.30661353]
# 0 0.09244493
# 1 [0.504903] [0.30513442]
# 1 0.04764305
# 2 [0.3893968] [0.30409035]
# 2 0.024765708
# 3 [0.3068576] [0.30334428]
# 3 0.013083752
# 4 [0.2478762] [0.30281115]
# 4 0.0071185543
# 5 [0.20572889] [0.30243018]
# 5 0.0040725223
# 6 [0.17561099] [0.30215794]
# 6 0.0025171146
# 7 [0.15408915] [0.3019634]
# 7 0.0017228713
